# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
boston_df=pd.read_csv(boston_url)

# %%
fig, ax = plt.subplots(figsize = (6, 4))
MEDV = sns.boxplot(x="MEDV", data=boston_df)
ax.set_xlabel("Median value of owner-occupied homes in $1000's", size = 10)
ax.set_title("Spread of the Median values of owner-occupied homes in $1000's", size = 12)
# Out:
# Text(0.5, 1.0, "Spread of the Median values of owner-occupied homes in $1000's")

# %%
fig, ax = plt.subplots(figsize = (5, 5))
CHAS = sns.barplot(boston_df["CHAS"])
ax.set_ylabel("Charles River dummy variable", size = 12)
ax.set_title("Barplot of Charles River Variable", size = 14)
# Out:
# Text(0.5, 1.0, 'Barplot of Charles River Variable')

# %%
boston_df.loc[(boston_df['AGE'] <= 35), 'age_group'] = '35 years and younger'
boston_df.loc[(boston_df['AGE'] > 35) & (boston_df['AGE'] < 70), 'age_group'] = 'between 35 and 70 years'
boston_df.loc[(boston_df['AGE'] >= 70), 'age_group'] = '70 years and older'

# %%
thirtyfive_lower = boston_df['age_group'] == '35 years and younger'
thirtyfive_seventy = boston_df['age_group'] == 'between 35 and 70 years'
seventy_older = boston_df['age_group'] == '70 years and older'

# %%
fig, ax = plt.subplots(figsize = (8, 6))
MEDV_AGE = sns.boxplot(x="age_group", y="MEDV", data=boston_df)
ax.set_xlabel("Age Groups", size = 12)
ax.set_ylabel("Median value of owner-occupied homes in $1000's", size = 12)
ax.set_title("Comparison of Median Values of different age groups", size = 14)
# Out:
# Text(0.5, 1.0, 'Comparison of Median Values of different age groups')

# %%
fig, ax = plt.subplots(figsize = (8, 6))
NOX_INDUS = sns.scatterplot(x='NOX', y='INDUS', data=boston_df)
ax.set_xlabel("Nitric Oxides concentration (parts per 10 million)", size = 10)
ax.set_ylabel("Proportion of non-retail business acres per town", size = 10)
ax.set_title("Relationship between Nitric Oxide concentrations and The Proportion of non-retail business acres per town", size = 8)
# Out:
# Text(0.5, 1.0, 'Relationship between Nitric Oxide concentrations and The Proportion of non-retail business acres per town')

# %%
fig, ax = plt.subplots(figsize = (6, 4))
PTRATIO = sns.histplot(x="PTRATIO", data=boston_df)
ax.set_xlabel("Pupil-Teacher Ratio by Town", size = 10)
ax.set_title("Histogram For The Pupil to Teacher Ratio Variable", size = 12)
# Out:
# Text(0.5, 1.0, 'Histogram For The Pupil to Teacher Ratio Variable')

# %%
import matplotlib.pyplot as plt
import scipy.stats

# %%
# H0: There is not a significant difference in median value of houses bounded by the Charles river.
# H1: There is a significant difference in median value of houses bounded by the Charles river.
scipy.stats.ttest_ind(boston_df["MEDV"], boston_df["CHAS"], equal_var=True)
# Out:
# Ttest_indResult(statistic=54.9210289745203, pvalue=1.4651540072350996e-305)

# %%
# for a = 0.05
# Conclusion: Since the p-value is greater than 0.05, we will fail to reject the null hypothesis 
#as there is no significant evidence that the median value of houses bounded by the Charles river differ.

# %%
# H0: There is a not difference in Median values of houses for each proportion of owner occupied units built prior to 1940.
# H1: There is a difference in Median values of houses for each proportion of owner occupied units built prior to 1940.
# for a = 0.05

f_statistic, p_value = scipy.stats.f_oneway(boston_df["MEDV"], boston_df["AGE"])
print("F_Statistic: {0}, P-Value: {1}".format(f_statistic,p_value))

# Conclusion: Since the p-value is less than 0.05, we will reject the null hypothesis
# as there is significant evidence that at least one of the median values for each proportion 
# of owner occupied units built prior to 1940 differ.
# Out:
# F_Statistic: 1223.1740271875933, P-Value: 3.20946197250671e-176

# %%
# H0: Nitric oxide concentrations is not correlated with proportion of non-retail business acres per town.
# H1: Nitric oxide concentrations is correlated with proportion of non-retail business acres per town.
# for a = 0.05

scipy.stats.pearsonr(boston_df["NOX"], boston_df["INDUS"])

# Conclusion: Since the p-value is less than 0.05, we will reject the null hypothesis
#  and conclude that there exists a relationship between Nitric oxide concentrations and proportion of non-retail business acres per town.
# Out:
# (0.7636514469209149, 7.913361061240043e-98)

# %%
import statsmodels.api as sm

# %%
# Null Hypothesis: additional weighted distance to the five Boston employment centres has no effect on the median value of owner occupied homes. 
# Alternative Hypothesis: additional weighted distance  to the five Boston employment centres has an effect on the median value of owner occupied homes. 

# X is the input variables (or independent variables)
X = boston_df['DIS']
# y is the target/dependent variable
y = boston_df['MEDV']
# add an intercept (beta_0) to our model
X = sm.add_constant(X) 

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Wed, 12 Oct 2022   Prob (F-statistic):           1.21e-08
# Time:                        20:16:44   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# ...

# %%
# Conclusion: Like the t-test, the p-value is less than the alpha (α) level = 0.05, 
#so we reject the null hypothesis as there is evidence that there is a difference in 
# median value of owner occupied homes.

# %%
# T-test
scipy.stats.ttest_ind(boston_df["DIS"], boston_df["MEDV"], equal_var=True)
# Out:
# Ttest_indResult(statistic=-44.673236529073336, pvalue=2.0336282784913355e-241)
